# %% [markdown]
# Check the column 'age' that's missing

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/footballers.csv')

print(df.columns)

print(df.columns.tolist())
# Out:
# Index(['name', 'club', 'league', 'nationality', 'position', 'age', 'height_cm',
#        'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physical', 'value_millions'],
#       dtype='str')
# ['name', 'club', 'league', 'nationality', 'position', 'age', 'height_cm', 'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physical', 'value_millions']

# %%
summary = df[['name', 'position', 'age', 'height_cm']]
summary
# Out:
#                       name position   age  height_cm
# 0             Lionel Messi       RW  37.0      170.0
# 1        Cristiano Ronaldo       ST  39.0      187.0
# 2            Kylian Mbappe       ST  26.0      178.0
# 3           Erling Haaland       ST  24.0      195.0
# 4          Kevin De Bruyne      CAM  33.0      181.0
# 5          Jude Bellingham       CM  21.0      186.0
# 6              Vinicius Jr       LW  24.0      176.0
# 7              Bukayo Saka       RW  23.0      178.0
# 8               Phil Foden       LW  24.0      171.0
# 9            Mohamed Salah       RW  32.0      175.0
# 10              Harry Kane       ST  31.0      188.0
# 11      Robert Lewandowski       ST  36.0      185.0
# 12           Jamal Musiala      CAM  21.0      183.0
# 13                   Pedri       CM  22.0      174.0
# 14                    Gavi       CM  20.0      173.0
# 15       Federico Valverde       CM  26.0      182.0
# 16                   Rodri      CDM  28.0      191.0
# ...

# %%
missing = df['age'].isna().sum()
print(missing)

# %%
clean = df[[]]

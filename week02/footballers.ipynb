# %%
import pandas as pd

# %%
File_Data = pd.read_csv('../data/footballers.csv')
File_Data
# Out:
#                       name                 club            league  \
# 0             Lionel Messi          Inter Miami               MLS
# 1        Cristiano Ronaldo             Al Nassr  Saudi Pro League
# 2            Kylian Mbappe          Real Madrid           La Liga
# 3           Erling Haaland      Manchester City    Premier League
# 4          Kevin De Bruyne      Manchester City    Premier League
# 5          Jude Bellingham          Real Madrid           La Liga
# 6              Vinicius Jr          Real Madrid           La Liga
# 7              Bukayo Saka              Arsenal    Premier League
# 8               Phil Foden      Manchester City    Premier League
# 9            Mohamed Salah            Liverpool    Premier League
# 10              Harry Kane        Bayern Munich        Bundesliga
# 11      Robert Lewandowski            Barcelona           La Liga
# 12           Jamal Musiala        Bayern Munich        Bundesliga
# ...

# %%
print(File_Data.head())
# Out:
#                 name             club            league nationality position  \
# 0       Lionel Messi      Inter Miami               MLS   Argentina       RW
# 1  Cristiano Ronaldo         Al Nassr  Saudi Pro League    Portugal       ST
# 2      Kylian Mbappe      Real Madrid           La Liga      France       ST
# 3     Erling Haaland  Manchester City    Premier League      Norway       ST
# 4    Kevin De Bruyne  Manchester City    Premier League     Belgium      CAM
#
#     age  height_cm  overall  pace  shooting  passing  dribbling  defending  \
# 0  37.0      170.0       90    87        90       91         94         34
# 1  39.0      187.0       86    78        89       82         83         32
# 2  26.0      178.0       91    97        88       80         92         36
# 3  24.0      195.0       91    89        91       66         80         45
# 4  33.0      181.0       88    76        89       94         88         64
#
#    physical value_millions
# ...

# %%
print(File_Data.tail())
# Out:
#                      name         club          league nationality position  \
# 41         Nicolo Barella  Inter Milan         Serie A       Italy       CM
# 42             Toni Kroos  Real Madrid         La Liga     Germany       CM
# 43       Thibaut Courtois  Real Madrid         La Liga     Belgium       GK
# 44         Alisson Becker    Liverpool  Premier League      Brazil       GK
# 45  Marc-Andre ter Stegen    Barcelona         La Liga     Germany       GK
#
#      age  height_cm  overall  pace  shooting  passing  dribbling  defending  \
# 41  27.0      172.0       85    76        78       84         84         74
# 42  34.0      183.0       55    74        93       88         76         65
# 43  32.0      199.0       46    20        42       60         40         20
# 44  32.0      191.0       48    22        48       62         42         22
# 45  32.0      187.0       40    18        52       68         38         18
#
#     physical value_millions
# ...

# %%
print(File_Data.shape)
# Out:
# (46, 15)

# %%
print(File_Data.columns)
print('-------------------------------------------')
print(File_Data.columns.tolist)
# Out:
# Index(['name', 'club', 'league', 'nationality', 'position', 'age', 'height_cm',
#        'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physical', 'value_millions'],
#       dtype='str')
# -------------------------------------------
# <bound method IndexOpsMixin.tolist of Index(['name', 'club', 'league', 'nationality', 'position', 'age', 'height_cm',
#        'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physical', 'value_millions'],
#       dtype='str')>

# %% [markdown]
# pd.read_csv() means to read file
#
# print(File_Data.head()) it shows the first 5 row
#
# print(File_Data.tail()) it shows the last 5 row
#
# print(File_Data.shape) it tells us the amout of columns and row
#
# print(File_Data.columns) tells names and data type also index
#
# print(File_Data.columns.tolist) tells only names
